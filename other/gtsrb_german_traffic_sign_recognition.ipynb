# %% [markdown]
# # *Traffic Sign Recognizer - 99% accuracy*

# %% [markdown]
# [GTSRB - German Traffic Sign Recognition Benchmark](https://www.kaggle.com/datasets/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign/code?datasetId=82373&sortBy=voteCount)
#
# [GTSRB - CNN (98% Test Accuracy)](https://www.kaggle.com/code/shivank856/gtsrb-cnn-98-test-accuracy)

# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd

import os
import cv2
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from keras import utils

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

np.random.seed(42)

# %% [markdown]
# ## Assigning Path for Dataset

# %%
data_dir = 'data/gtsrb_german_traffic_sign'
train_path = 'data/gtsrb_german_traffic_sign/Train'
test_path = 'data/gtsrb_german_traffic_sign/Test'

# %%
# Resizing the images to 30x30x3
IMG_HEIGHT = 20 # 30
IMG_WIDTH = 20 # 30
channels = 3

# %% [markdown]
# ## Finding Total Classes

# %%
NUM_CATEGORIES = len(os.listdir(train_path))
NUM_CATEGORIES
# Out:
# 43

# %%
# Label Overview
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %% [markdown]
# ## Visualizing The Dataset

# %%
folders = os.listdir(train_path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])
    
# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(21,10))  
plt.bar(class_num, train_number)
plt.xticks(class_num, rotation='vertical')
plt.grid()
plt.show()

# %%
# Visualizing 25 random images from test data
import random
from matplotlib.image import imread

test = pd.read_csv(data_dir + '/Test.csv')
imgs = test["Path"].values

plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    random_img_path = data_dir + '/' + random.choice(imgs)
    rand_img = imread(random_img_path)
    plt.imshow(rand_img)
    
    plt.xticks([])
    plt.yticks([])
    
    plt.xlabel(rand_img.shape[1], fontsize = 20)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 20)#height of image

# %% [markdown]
# ## Collecting the Training Data

# %%
image_data = []
image_labels = []

for i in range(NUM_CATEGORIES):
    path = data_dir + '/Train/' + str(i)
    images = os.listdir(path)

    for img in images:
        try:
            image = cv2.imread(path + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# (39209, 20, 20, 3) (39209,)

# %% [markdown]
# ## Shuffling the training data

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %% [markdown]
# ## Splitting the data into train and validation set

# %%
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.3, random_state=42, shuffle=True)

X_train = X_train/255 
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (27446, 20, 20, 3)
# X_valid.shape (11763, 20, 20, 3)
# y_train.shape (27446,)
# y_valid.shape (11763,)

# %% [markdown]
# ## One hot encoding the labels

# %%
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 43)
# (11763, 43)

# %% [markdown]
# ## Making the model

# %%
model = keras.models.Sequential([    
    keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same', input_shape=(IMG_HEIGHT,IMG_WIDTH,channels)),  # 20 x 20 x 16
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'), # 20 x 20 x 32
    keras.layers.MaxPool2D(pool_size=(2,2)),  # 10 x 10 x 32
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'),  # 10 x 10 x 64
    keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'),  # 10 x 10 x 128
    keras.layers.MaxPool2D(pool_size=(2,2)), # 5 x 5 x 128
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Flatten(), # 5 x 5 x 128 = 3200
    keras.layers.Dense(25, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(rate=0.5),
    
    keras.layers.Dense(43, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 20, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 32)        4640
#
#  max_pooling2d (MaxPooling2D  (None, 10, 10, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 10, 10, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 5, 5, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 25)                80025
#
#  batch_normalization_2 (Batc  (None, 25)               100
#  hNormalization)
#
#  dropout (Dropout)           (None, 25)                0
#
#  dense_1 (Dense)             (None, 43)                1118
#
# =================================================================
# Total params: 179,323
# Trainable params: 178,953
# Non-trainable params: 370
# _________________________________________________________________

# %%
utils.plot_model(model, 'images/gtsrb_german_traffic_sign_recognition.png', show_shapes=True, dpi=70)

# %%
lr = 0.001
epochs = 15 # 30

opt = Adam(learning_rate=lr) #, decay=lr / (epochs * 0.5))
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## Augmenting the data and training the model

# %%
aug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

history = model.fit(aug.flow(X_train, y_train, batch_size=32), epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/15
# 858/858 [==============================] - 25s 28ms/step - loss: 2.2011 - accuracy: 0.4268 - val_loss: 0.5593 - val_accuracy: 0.8681
# Epoch 2/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.7458 - accuracy: 0.7951 - val_loss: 0.2077 - val_accuracy: 0.9512
# Epoch 3/15
# 858/858 [==============================] - 24s 28ms/step - loss: 0.4321 - accuracy: 0.8774 - val_loss: 0.1337 - val_accuracy: 0.9640
# Epoch 4/15
# 858/858 [==============================] - 25s 29ms/step - loss: 0.3299 - accuracy: 0.9035 - val_loss: 0.0683 - val_accuracy: 0.9810
# Epoch 5/15
# 858/858 [==============================] - 24s 28ms/step - loss: 0.2678 - accuracy: 0.9214 - val_loss: 0.0520 - val_accuracy: 0.9846
# Epoch 6/15
# 858/858 [==============================] - 26s 30ms/step - loss: 0.2267 - accuracy: 0.9325 - val_loss: 0.0454 - val_accuracy: 0.9882
# Epoch 7/15
# 858/858 [==============================] - 23s 27ms/step - loss: 0.2064 - accuracy: 0.9378 - val_loss: 0.0279 - val_accuracy: 0.9919
# Epoch 8/15
# 858/858 [==============================] - 23s 27ms/step - loss: 0.1785 - accuracy: 0.9460 - val_loss: 0.0849 - val_accuracy: 0.9724
# Epoch 9/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1576 - accuracy: 0.9523 - val_loss: 0.0297 - val_accuracy: 0.9909
# Epoch 10/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1584 - accuracy: 0.9516 - val_loss: 0.0337 - val_accuracy: 0.9901
# Epoch 11/15
# 858/858 [==============================] - 23s 27ms/step - loss: 0.1466 - accuracy: 0.9546 - val_loss: 0.0158 - val_accuracy: 0.9948
# Epoch 12/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1346 - accuracy: 0.9599 - val_loss: 0.0424 - val_accuracy: 0.9870
# Epoch 13/15
# 858/858 [==============================] - 24s 28ms/step - loss: 0.1237 - accuracy: 0.9620 - val_loss: 0.0520 - val_accuracy: 0.9830
# Epoch 14/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1189 - accuracy: 0.9640 - val_loss: 0.0215 - val_accuracy: 0.9940
# Epoch 15/15
# 858/858 [==============================] - 22s 26ms/step - loss: 0.1165 - accuracy: 0.9643 - val_loss: 0.0120 - val_accuracy: 0.9959

# %% [markdown]
# ## Evaluating the model

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Loading the test data and running the predictions

# %%
test = pd.read_csv(data_dir + '/Test.csv')

labels = test["ClassId"].values
imgs = test["Path"].values

data =[]

for img in imgs:
    try:
        image = cv2.imread(data_dir + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        data.append(np.array(resize_image))
    except:
        print("Error in " + img)
X_test = np.array(data)
X_test = X_test/255

pred = model.predict(X_test)
pred = np.argmax(pred, axis=1)

#Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(labels, pred)*100)
# Out:
# 395/395 [==============================] - 2s 6ms/step
# Test Data accuracy:  97.13380839271576

# %% [markdown]
# ## Visualizing the confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(labels, pred)

# %%
import seaborn as sns
df_cm = pd.DataFrame(cf, index = classes,  columns = classes)
plt.figure(figsize = (20,20))
sns.heatmap(df_cm, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Classification report

# %%
from sklearn.metrics import classification_report

print(classification_report(labels, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        60
#            1       0.92      1.00      0.96       720
#            2       0.98      0.97      0.98       750
#            3       0.98      0.99      0.99       450
#            4       1.00      0.96      0.98       660
#            5       0.98      0.95      0.97       630
#            6       1.00      0.91      0.95       150
#            7       0.99      0.98      0.99       450
#            8       0.99      0.98      0.99       450
#            9       1.00      1.00      1.00       480
#           10       1.00      1.00      1.00       660
#           11       0.98      0.93      0.96       420
#           12       1.00      0.99      0.99       690
#           13       1.00      0.99      1.00       720
#           14       1.00      1.00      1.00       270
#           15       0.99      0.97      0.98       210
#           16       1.00      1.00      1.00       150
#           17       1.00      1.00      1.00       360
#           18       0.99      0.85      0.92       390
#           19       1.00      0.97      0.98        60
#           20       0.82      1.00      0.90        90
#           21       0.89      0.66      0.76        90
#           22       1.00      0.88      0.93       120
#           23       0.98      1.00      0.99       150
#           24       0.97      1.00      0.98        90
#           25       0.96      0.99      0.98       480
#           26       0.96      0.99      0.98       180
#           27       0.60      0.50      0.55        60
#           28       0.78      0.99      0.87       150
#           29       0.85      1.00      0.92        90
#           30       0.86      0.93      0.89       150
#           31       0.96      0.99      0.97       270
#           32       0.82      1.00      0.90        60
#           33       1.00      1.00      1.00       210
#           34       1.00      1.00      1.00       120
#           35       0.99      1.00      1.00       390
#           36       0.95      1.00      0.98       120
#           37       0.98      1.00      0.99        60
#           38       1.00      0.99      1.00       690
#           39       0.99      0.98      0.98        90
#           40       0.98      0.98      0.98        90
#           41       0.67      1.00      0.81        60
#           42       0.94      0.69      0.79        90
#
#     accuracy                           0.97     12630
#    macro avg       0.95      0.95      0.95     12630
# weighted avg       0.97      0.97      0.97     12630

# %% [markdown]
# ## Predictions on Test Data

# %%
plt.figure(figsize = (25, 25))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = pred[start_index + i]
    actual = labels[start_index + i]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}\n{}'.format(actual, prediction, classes[prediction]), color = col)
    plt.imshow(X_test[start_index + i])
plt.show()
